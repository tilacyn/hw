# %%
import pandas as pd
import numpy as np
import plots
import smo1
import kernels
import math


class_dict = {
    'N': -1,
    'P': 1
}

def fscore_inner(precision, recall):
    return 2 * (precision * recall) / (precision + recall)

def fscore(classify, test_set):
    mtx = np.array([[0, 0], [0, 0]])
    for x in test_set:
        classified = classify(x)
        expected = class_dict[x[2]]
        if expected == -1 and classified == -1:
            mtx[0][0] += 1
        if expected == 1 and classified == -1:
            mtx[1][0] += 1
        if expected == -1 and classified == 1:
            mtx[0][1] += 1
        if expected == 1 and classified == 1:
            mtx[1][1] += 1
    w = mtx.sum(0)
    w = list(map(lambda x: x / mtx.sum(), w))
    f1 = fscore_inner(mtx[0][0] / mtx.sum(0)[0], mtx[0][0] / mtx.sum(1)[0])
    f2 = fscore_inner(mtx[1][1] / mtx.sum(0)[1], mtx[1][1] / mtx.sum(1)[1])
    return f1 * w[0] + f2 * w[1], mtx



def draw(classify, data):
    return plots.draw(classify, data, minmax[0], minmax[1], minmax[2], minmax[3])

def draw_on_data(model, data):
    draw(model.predict, data)

def separate(data, k):
    shuffled = data.copy()
    np.random.shuffle(shuffled)
    return shuffled[:k], shuffled[k:]


def run_svm(kernel_f, train_set, c):
    n = len(train_set)
    kernel = np.zeros([n, n])
    y = []

    for i in range(n):
        for j in range(n):
            kernel[i][j] = kernel_f(train_set[i], train_set[j])
        y.append(class_dict[train_set[i][2]])

    smo_model = smo1.SMO(train_set, kernel, kernel_f, y, c)
    smo_model.solve()

    #draw(lambda x: smo_model.predict(train_set, x), train_set)
    return smo_model


times = range(5)

def run_cv(kernel, data, train_set_n, c):
    sum_f = 0
    for t in times:
        train_set, test_set = separate(data, train_set_n)
        model = run_svm(kernel, train_set, c)
        f, mtx = fscore(model.predict, test_set)
        print("c:", c, "t:", t, "fscore:", f)
        sum_f += f
    return [model, sum_f / len(times), c]


def sort_and_filter(res):
    res = list(filter(lambda x: not math.isnan(x[1]), res))
    res.sort(key=lambda x: -x[1])
    return res

minmax = []

def run(train_set_n, file):
    minmax.clear()
    dataframe = pd.read_csv(file)

    dataframe.info()

    data = dataframe.values

    minmax.append(min(data, key=lambda x: x[1])[1])
    minmax.append(max(data, key=lambda x: x[1])[1])
    minmax.append(min(data, key=lambda x: x[0])[0])
    minmax.append(max(data, key=lambda x: x[0])[0])
    cs = [1, 5, 10, 100]
    gammas = np.linspace(0.2, 1.6, 8)

    exp_results = []
    pol_results = []
    s2d_results = []

    for c in cs:
        for gamma in gammas:
            result = run_cv(kernels.exponentialg(gamma), data, train_set_n, c)
            result.append(gamma)
            exp_results.append(result)

        s2d_result = run_cv(kernels.scalar_2d, data, train_set_n, c)
        s2d_results.append(s2d_result)

        pol_result = run_cv(kernels.polynomial2, data, train_set_n, c)
        pol_results.append(pol_result)

    
    return exp_results, s2d_results, pol_results, data

# %%
exp_res, s2d_res, pol_res, data = run(80, 'data/chips.csv')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 118 entries, 0 to 117
# Data columns (total 3 columns):
# x        118 non-null float64
# y        118 non-null float64
# class    118 non-null object
# dtypes: float64(2), object(1)
# memory usage: 2.9+ KB
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:33: RuntimeWarning: invalid value encountered in long_scalars
# c: 1 t: 0 fscore: nan
# c: 1 t: 1 fscore: 0.6352057337766073
# c: 1 t: 2 fscore: nan
# c: 1 t: 3 fscore: 0.34164934164934163
# c: 1 t: 4 fscore: nan
# c: 1 t: 0 fscore: 0.680672268907563
# c: 1 t: 1 fscore: 0.7948564593301435
# c: 1 t: 2 fscore: 0.4982674982674983
# c: 1 t: 3 fscore: 0.5789871504157219
# c: 1 t: 4 fscore: 0.7095232884706568
# c: 1 t: 0 fscore: 0.7714770797962648
# c: 1 t: 1 fscore: 0.6290726817042607
# c: 1 t: 2 fscore: nan
# c: 1 t: 3 fscore: 0.5851256902343901
# c: 1 t: 4 fscore: 0.6310130164119978
# c: 1 t: 0 fscore: 0.7077067669172933
# c: 1 t: 1 fscore: 0.7912679425837321
# c: 1 t: 2 fscore: 0.7930622009569378
# c: 1 t: 3 fscore: 0.6842105263157896
# c: 1 t: 4 fscore: 0.7791353383458648
# c: 1 t: 0 fscore: 0.8965311004784688
# c: 1 t: 1 fscore: 0.6859649122807017
# c: 1 t: 2 fscore: 0.6545209176788125
# c: 1 t: 3 fscore: 0.7656615110715477
# c: 1 t: 4 fscore: 0.6788277511961722
# c: 1 t: 0 fscore: 0.7119305540358172
# c: 1 t: 1 fscore: 0.67677796642143
# c: 1 t: 2 fscore: 0.6290726817042607
# c: 1 t: 3 fscore: 0.6885964912280703
# c: 1 t: 4 fscore: 0.7383040935672515
# c: 1 t: 0 fscore: 0.8421052631578947
# c: 1 t: 1 fscore: 0.7338935574229692
# c: 1 t: 2 fscore: 0.657179534201357
# c: 1 t: 3 fscore: 0.8681459746928295
# c: 1 t: 4 fscore: 0.7894736842105261
# c: 1 t: 0 fscore: 0.7545546558704453
# c: 1 t: 1 fscore: 0.7709773332818474
# c: 1 t: 2 fscore: 0.7129331264669612
# c: 1 t: 3 fscore: 0.710726921253237
# c: 1 t: 4 fscore: 0.7368421052631577
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:32: RuntimeWarning: invalid value encountered in long_scalars
# c: 1 t: 0 fscore: nan
# c: 1 t: 1 fscore: 0.45321019250027816
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:15: RuntimeWarning: invalid value encountered in double_scalars
#   from ipykernel import kernelapp as app
# c: 1 t: 2 fscore: nan
# c: 1 t: 3 fscore: 0.41783625730994145
# c: 1 t: 4 fscore: nan
# c: 1 t: 0 fscore: 0.7738539898132428
# c: 1 t: 1 fscore: nan
# c: 1 t: 2 fscore: 0.6842105263157895
# c: 1 t: 3 fscore: nan
# c: 1 t: 4 fscore: 0.6811740890688259
# c: 5 t: 0 fscore: 0.6004784688995215
# c: 5 t: 1 fscore: 0.6060883917109848
# c: 5 t: 2 fscore: 0.6699113374834937
# c: 5 t: 3 fscore: 0.562358276643991
# c: 5 t: 4 fscore: 0.5861244019138756
# c: 5 t: 0 fscore: 0.7235993208828523
# c: 5 t: 1 fscore: 0.8164277637961848
# c: 5 t: 2 fscore: 0.8161745827984597
# c: 5 t: 3 fscore: 0.6093893269759766
# c: 5 t: 4 fscore: 0.7894736842105263
# c: 5 t: 0 fscore: 0.6346491228070175
# c: 5 t: 1 fscore: 0.7075004584632312
# c: 5 t: 2 fscore: 0.7626627544470932
# c: 5 t: 3 fscore: 0.8685122369332896
# c: 5 t: 4 fscore: 0.7595925297113751
# c: 5 t: 0 fscore: 0.8421052631578947
# c: 5 t: 1 fscore: 0.7427392009435355
# c: 5 t: 2 fscore: 0.6761363636363635
# c: 5 t: 3 fscore: 0.5824561403508772
# c: 5 t: 4 fscore: 0.7673305886280182
# c: 5 t: 0 fscore: 0.8429824561403509
# c: 5 t: 1 fscore: 0.631578947368421
# c: 5 t: 2 fscore: 0.6761363636363635
# c: 5 t: 3 fscore: 0.687218045112782
# c: 5 t: 4 fscore: 0.7667232597623088
# c: 5 t: 0 fscore: 0.7992372234935163
# c: 5 t: 1 fscore: 0.709921144324225
# c: 5 t: 2 fscore: 0.7656615110715477
# c: 5 t: 3 fscore: 0.8190349022662364
# c: 5 t: 4 fscore: 0.6859796550199027
# c: 5 t: 0 fscore: 0.7162605707224776
# c: 5 t: 1 fscore: 0.739084928229665
# c: 5 t: 2 fscore: 0.564790023840088
# c: 5 t: 3 fscore: 0.7882942650744508
# c: 5 t: 4 fscore: 0.6518675123326286
# c: 5 t: 0 fscore: 0.8164277637961848
# c: 5 t: 1 fscore: 0.7894736842105263
# c: 5 t: 2 fscore: 0.7626654995076046
# c: 5 t: 3 fscore: 0.736842105263158
# c: 5 t: 4 fscore: 0.7383163791832523
# c: 5 t: 0 fscore: 0.446035724231213
# c: 5 t: 1 fscore: 0.631578947368421
# c: 5 t: 2 fscore: 0.4747520976353929
# c: 5 t: 3 fscore: 0.43078283945157003
# c: 5 t: 4 fscore: nan
# c: 5 t: 0 fscore: 0.7673305886280182
# c: 5 t: 1 fscore: 0.7912679425837321
# c: 5 t: 2 fscore: 0.62953216374269
# c: 5 t: 3 fscore: 0.7912679425837321
# c: 5 t: 4 fscore: 0.7912679425837321
# c: 10 t: 0 fscore: 0.5592677345537757
# c: 10 t: 1 fscore: 0.657179534201357
# c: 10 t: 2 fscore: 0.5542079299729239
# c: 10 t: 3 fscore: 0.6129718234981394
# c: 10 t: 4 fscore: 0.761672473867596
# c: 10 t: 0 fscore: 0.7339181286549707
# c: 10 t: 1 fscore: 0.7606821932880983
# c: 10 t: 2 fscore: 0.5458970005659309
# c: 10 t: 3 fscore: 0.7948564593301435
# c: 10 t: 4 fscore: 0.5342768686421937
# c: 10 t: 0 fscore: 0.8170058307912114
# c: 10 t: 1 fscore: 0.7398932112890921
# c: 10 t: 2 fscore: 0.6591001817440005
# c: 10 t: 3 fscore: 0.8686946055367109
# c: 10 t: 4 fscore: 0.7265044331258252
# c: 10 t: 0 fscore: 0.8690813054140729
# c: 10 t: 1 fscore: 0.7629937629937629
# c: 10 t: 2 fscore: 0.7643463497453311
# c: 10 t: 3 fscore: 0.5983086680761099
# c: 10 t: 4 fscore: 0.7870327993897788
# c: 10 t: 0 fscore: 0.7353801169590644
# c: 10 t: 1 fscore: 0.7368421052631577
# c: 10 t: 2 fscore: 0.7912280701754386
# c: 10 t: 3 fscore: 0.6643315606088392
# c: 10 t: 4 fscore: 0.8161745827984597
# c: 10 t: 0 fscore: 0.6401220442410374
# c: 10 t: 1 fscore: 0.5954592363261094
# c: 10 t: 2 fscore: 0.7197062423500613
# c: 10 t: 3 fscore: 0.8164385594006157
# c: 10 t: 4 fscore: 0.7882942650744508
# c: 10 t: 0 fscore: 0.7894736842105263
# c: 10 t: 1 fscore: 0.8161745827984597
# c: 10 t: 2 fscore: 0.7383040935672515
# c: 10 t: 3 fscore: 0.7629937629937629
# c: 10 t: 4 fscore: 0.7368421052631579
# c: 10 t: 0 fscore: 0.6842105263157895
# c: 10 t: 1 fscore: 0.7383163791832523
# c: 10 t: 2 fscore: 0.694976076555024
# c: 10 t: 3 fscore: 0.895029239766082
# c: 10 t: 4 fscore: 0.7390350877192983
# c: 10 t: 0 fscore: 0.4780701754385965
# c: 10 t: 1 fscore: nan
# c: 10 t: 2 fscore: 0.3157894736842105
# c: 10 t: 3 fscore: 0.48872180451127817
# c: 10 t: 4 fscore: 0.47663275836650454
# c: 10 t: 0 fscore: 0.631578947368421
# c: 10 t: 1 fscore: 0.709921144324225
# c: 10 t: 2 fscore: 0.7368421052631577
# c: 10 t: 3 fscore: 0.6850877192982456
# c: 10 t: 4 fscore: 0.6398348813209495
# c: 100 t: 0 fscore: 0.8429898275099514
# c: 100 t: 1 fscore: 0.7636502899660794
# c: 100 t: 2 fscore: 0.7383163791832523
# c: 100 t: 3 fscore: 0.7666238767650834
# c: 100 t: 4 fscore: 0.8681459746928295
# c: 100 t: 0 fscore: 0.7894736842105261
# c: 100 t: 1 fscore: 0.7606542784021363
# c: 100 t: 2 fscore: 0.7075004584632312
# c: 100 t: 3 fscore: 0.8953265516733009
# c: 100 t: 4 fscore: 0.8698119505953044
# c: 100 t: 0 fscore: 0.7595925297113751
# c: 100 t: 1 fscore: 0.660502607871029
# c: 100 t: 2 fscore: 0.6930561698363557
# c: 100 t: 3 fscore: 0.8953265516733009
# c: 100 t: 4 fscore: 0.6850877192982456
# c: 100 t: 0 fscore: 0.7111281321807639
# c: 100 t: 1 fscore: 0.7639785534522376
# c: 100 t: 2 fscore: 0.765633596185586
# c: 100 t: 3 fscore: 0.868884685286154
# c: 100 t: 4 fscore: 0.8686946055367109
# c: 100 t: 0 fscore: 0.8439359267734554
# c: 100 t: 1 fscore: 0.7338935574229692
# c: 100 t: 2 fscore: 0.631578947368421
# c: 100 t: 3 fscore: 0.8167138275797019
# c: 100 t: 4 fscore: 0.631578947368421
# c: 100 t: 0 fscore: 0.7368421052631577
# c: 100 t: 1 fscore: 0.791812865497076
# c: 100 t: 2 fscore: 0.7900584795321638
# c: 100 t: 3 fscore: 0.7639785534522376
# c: 100 t: 4 fscore: 0.8204112431616677
# c: 100 t: 0 fscore: 0.8159171317066054
# c: 100 t: 1 fscore: 0.7156262749898001
# c: 100 t: 2 fscore: 0.631578947368421
# c: 100 t: 3 fscore: 0.8421052631578947
# c: 100 t: 4 fscore: 0.7119305540358172
# c: 100 t: 0 fscore: 0.8146341463414635
# c: 100 t: 1 fscore: 0.8156618156618156
# c: 100 t: 2 fscore: 0.8947368421052632
# c: 100 t: 3 fscore: 0.8692898791365795
# c: 100 t: 4 fscore: 0.6590801327643433
# c: 100 t: 0 fscore: nan
# c: 100 t: 1 fscore: 0.5441729323308271
# c: 100 t: 2 fscore: 0.441591784338896
# c: 100 t: 3 fscore: 0.4795321637426901
# c: 100 t: 4 fscore: 0.47336032388663973
# c: 100 t: 0 fscore: 0.7894736842105263
# c: 100 t: 1 fscore: 0.6872610727111248
# c: 100 t: 2 fscore: 0.8429824561403509
# c: 100 t: 3 fscore: 0.6357069143446852
# c: 100 t: 4 fscore: 0.7119305540358172

# %%
s2d_res = sort_and_filter(s2d_res)
pol_res = sort_and_filter(pol_res)
exp_res = sort_and_filter(exp_res)

# %%
best_exp_chips = exp_res[0]
print("c:", best_exp_chips[2], "gamma:", best_exp_chips[3], "avg f:", best_exp_chips[1])
draw_on_data(best_exp_chips[0], data)
# Out:
# c: 100 gamma: 1.6 avg f: 0.810680563201893
# No handles with labels found to put in legend.

# %%
best_pol_chips = pol_res[0]
print("c:", best_pol_chips[2], "avg f:", best_pol_chips[1])
draw_on_data(best_pol_chips[0], data)
# Out:
# c: 5 avg f: 0.7541333160243809
# No handles with labels found to put in legend.

# %%
gexp_res, gs2d_res, gpol_res, gdata = run(160, 'data/geyser.csv')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 222 entries, 0 to 221
# Data columns (total 3 columns):
# x        222 non-null int64
# y        222 non-null float64
# class    222 non-null object
# dtypes: float64(1), int64(1), object(1)
# memory usage: 5.3+ KB
# c: 1 t: 0 fscore: 0.9369825034655876
# c: 1 t: 1 fscore: 0.9032258064516129
# c: 1 t: 2 fscore: 0.9057603686635944
# c: 1 t: 3 fscore: 0.8804132405650432
# c: 1 t: 4 fscore: 0.8762463343108505
# c: 1 t: 0 fscore: 0.9074900304023374
# c: 1 t: 1 fscore: 0.8566436994714277
# c: 1 t: 2 fscore: 0.8590503525301054
# c: 1 t: 3 fscore: 0.9048142717497556
# c: 1 t: 4 fscore: 0.9052052785923753
# c: 1 t: 0 fscore: 0.9520801778866296
# c: 1 t: 1 fscore: 0.8726062467997951
# c: 1 t: 2 fscore: 0.937173579109063
# c: 1 t: 3 fscore: 0.8736070381231671
# c: 1 t: 4 fscore: 0.8594601711652403
# c: 1 t: 0 fscore: 0.8932347252703206
# c: 1 t: 1 fscore: 0.8744201100442335
# c: 1 t: 2 fscore: 0.9368035190615835
# c: 1 t: 3 fscore: 0.9373790816125085
# c: 1 t: 4 fscore: 0.889727324655022
# c: 1 t: 0 fscore: 0.9205462122984412
# c: 1 t: 1 fscore: 0.9366346603373251
# c: 1 t: 2 fscore: 0.8336593198073274
# c: 1 t: 3 fscore: 0.922486446401908
# c: 1 t: 4 fscore: 0.8283468933309073
# c: 1 t: 0 fscore: 0.8407427487123882
# c: 1 t: 1 fscore: 0.8749266862170089
# c: 1 t: 2 fscore: 0.9518768581034147
# c: 1 t: 3 fscore: 0.8440045617464973
# c: 1 t: 4 fscore: 0.9189149139136635
# c: 1 t: 0 fscore: 0.8629008559809656
# c: 1 t: 1 fscore: 0.8898924731182796
# c: 1 t: 2 fscore: 0.8293554870199031
# c: 1 t: 3 fscore: 0.8919738750438417
# c: 1 t: 4 fscore: 0.8569211923233973
# c: 1 t: 0 fscore: 0.9202106649111259
# c: 1 t: 1 fscore: 0.935483870967742
# c: 1 t: 2 fscore: 0.8236755045358458
# c: 1 t: 3 fscore: 0.9021018320782286
# c: 1 t: 4 fscore: 0.8578470260007665
# c: 1 t: 0 fscore: 0.9524047678586313
# c: 1 t: 1 fscore: 0.7353184449958643
# c: 1 t: 2 fscore: 0.7662092890798944
# c: 1 t: 3 fscore: 0.9054737551983816
# c: 1 t: 4 fscore: 0.8713743561940905
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:33: RuntimeWarning: invalid value encountered in long_scalars
# c: 1 t: 0 fscore: nan
# c: 1 t: 1 fscore: 0.7581472291149711
# c: 1 t: 2 fscore: 0.7303681981101335
# c: 1 t: 3 fscore: 0.789942040864118
# c: 1 t: 4 fscore: 0.7970863683662851
# c: 5 t: 0 fscore: 0.8730355665839536
# c: 5 t: 1 fscore: 0.9065977295717658
# c: 5 t: 2 fscore: 0.9218431554700313
# c: 5 t: 3 fscore: 0.9363287250384025
# c: 5 t: 4 fscore: 0.8583095140873825
# c: 5 t: 0 fscore: 0.8887164829181979
# c: 5 t: 1 fscore: 0.8598744708801636
# c: 5 t: 2 fscore: 0.8686661631963175
# c: 5 t: 3 fscore: 0.8762463343108505
# c: 5 t: 4 fscore: 0.8766533738697834
# c: 5 t: 0 fscore: 0.8739650069311754
# c: 5 t: 1 fscore: 0.9358285084091537
# c: 5 t: 2 fscore: 0.8905804176580439
# c: 5 t: 3 fscore: 0.904711375212224
# c: 5 t: 4 fscore: 0.8908760945510639
# c: 5 t: 0 fscore: 0.8639030798423587
# c: 5 t: 1 fscore: 0.8739650069311754
# c: 5 t: 2 fscore: 0.9369825034655876
# c: 5 t: 3 fscore: 0.8428945074106364
# c: 5 t: 4 fscore: 0.9046472144351878
# c: 5 t: 0 fscore: 0.8744201100442335
# c: 5 t: 1 fscore: 0.8887164829181979
# c: 5 t: 2 fscore: 0.8330898055524334
# c: 5 t: 3 fscore: 0.8738961336078701
# c: 5 t: 4 fscore: 0.7888678051865908
# c: 5 t: 0 fscore: 0.8387096774193548
# c: 5 t: 1 fscore: 0.8587980328415438
# c: 5 t: 2 fscore: 0.9054541595925297
# c: 5 t: 3 fscore: 0.8736070381231671
# c: 5 t: 4 fscore: 0.8262574762231591
# c: 5 t: 0 fscore: 0.8903724964123041
# c: 5 t: 1 fscore: 0.9210261255559814
# c: 5 t: 2 fscore: 0.8267143673150348
# c: 5 t: 3 fscore: 0.827298484572795
# c: 5 t: 4 fscore: 0.7727703984819734
# c: 5 t: 0 fscore: 0.9061950146627565
# c: 5 t: 1 fscore: 0.8755708994138167
# c: 5 t: 2 fscore: 0.8574061882817643
# c: 5 t: 3 fscore: 0.8857466160321636
# c: 5 t: 4 fscore: 0.8428945074106364
# c: 5 t: 0 fscore: 0.8755708994138167
# c: 5 t: 1 fscore: 0.8480761305308907
# c: 5 t: 2 fscore: 0.7757776497695853
# c: 5 t: 3 fscore: 0.8332268252248247
# c: 5 t: 4 fscore: 0.7637014099750474
# c: 5 t: 0 fscore: 0.7840112201963534
# c: 5 t: 1 fscore: nan
# c: 5 t: 2 fscore: 0.6640515427769987
# c: 5 t: 3 fscore: 0.8065624653586075
# c: 5 t: 4 fscore: 0.7948555766392579
# c: 10 t: 0 fscore: 0.9061950146627565
# c: 10 t: 1 fscore: 0.8897962887346309
# c: 10 t: 2 fscore: 0.9368035190615835
# c: 10 t: 3 fscore: 0.839571271022884
# c: 10 t: 4 fscore: 0.9210334257772588
# c: 10 t: 0 fscore: 0.8569831821371942
# c: 10 t: 1 fscore: 0.8569211923233973
# c: 10 t: 2 fscore: 0.8905804176580439
# c: 10 t: 3 fscore: 0.9040888984788004
# c: 10 t: 4 fscore: 0.8285195771516719
# c: 10 t: 0 fscore: 0.888310787374263
# c: 10 t: 1 fscore: 0.8043837882547559
# c: 10 t: 2 fscore: 0.8887646972178176
# c: 10 t: 3 fscore: 0.8737248414667769
# c: 10 t: 4 fscore: 0.9042597187758479
# c: 10 t: 0 fscore: 0.905815082533175
# c: 10 t: 1 fscore: 0.935483870967742
# c: 10 t: 2 fscore: 0.8293554870199031
# c: 10 t: 3 fscore: 0.8552676041693743
# c: 10 t: 4 fscore: 0.8453079178885631
# c: 10 t: 0 fscore: 0.88809752800811
# c: 10 t: 1 fscore: 0.8566436994714277
# c: 10 t: 2 fscore: 0.8709677419354838
# c: 10 t: 3 fscore: 0.8532982225148125
# c: 10 t: 4 fscore: 0.8719581211092247
# c: 10 t: 0 fscore: 0.83024466078318
# c: 10 t: 1 fscore: 0.8582208459850283
# c: 10 t: 2 fscore: 0.9047766749379652
# c: 10 t: 3 fscore: 0.8368363867970476
# c: 10 t: 4 fscore: 0.8277282086479065
# c: 10 t: 0 fscore: 0.8729485002829656
# c: 10 t: 1 fscore: 0.8277282086479065
# c: 10 t: 2 fscore: 0.836617262423714
# c: 10 t: 3 fscore: 0.8521513275762372
# c: 10 t: 4 fscore: 0.8544915261502062
# c: 10 t: 0 fscore: 0.8572143035758939
# c: 10 t: 1 fscore: 0.7544903953627407
# c: 10 t: 2 fscore: 0.872657450076805
# c: 10 t: 3 fscore: 0.8709677419354839
# c: 10 t: 4 fscore: 0.8544098151854643
# c: 10 t: 0 fscore: 0.9047766749379652
# c: 10 t: 1 fscore: 0.78809937306778
# c: 10 t: 2 fscore: 0.8361212475064467
# c: 10 t: 3 fscore: 0.7832433221427528
# c: 10 t: 4 fscore: 0.722397026446443
# c: 10 t: 0 fscore: 0.7689708141321044
# c: 10 t: 1 fscore: 0.7590245775729646
# c: 10 t: 2 fscore: nan
# c: 10 t: 3 fscore: 0.8704876763655524
# c: 10 t: 4 fscore: 0.7632925472747497
# c: 100 t: 0 fscore: 0.8109083191850593
# c: 100 t: 1 fscore: 0.8734786399302529
# c: 100 t: 2 fscore: 0.8282290980908491
# c: 100 t: 3 fscore: 0.9364742501414827
# c: 100 t: 4 fscore: 0.8566436994714277
# c: 100 t: 0 fscore: 0.8582208459850283
# c: 100 t: 1 fscore: 0.8387096774193548
# c: 100 t: 2 fscore: 0.8722873900293254
# c: 100 t: 3 fscore: 0.8401481641313338
# c: 100 t: 4 fscore: 0.8724663744333296
# c: 100 t: 0 fscore: 0.7891787761755253
# c: 100 t: 1 fscore: 0.8864000455006493
# c: 100 t: 2 fscore: 0.8481857306431871
# c: 100 t: 3 fscore: 0.8234290640170592
# c: 100 t: 4 fscore: 0.8554403729420887
# c: 100 t: 0 fscore: 0.8611092679135108
# c: 100 t: 1 fscore: 0.8411856253537069
# c: 100 t: 2 fscore: 0.8446131140628295
# c: 100 t: 3 fscore: 0.937173579109063
# c: 100 t: 4 fscore: 0.8877935028864474
# c: 100 t: 0 fscore: 0.8403592375366569
# c: 100 t: 1 fscore: 0.9044930875576037
# c: 100 t: 2 fscore: 0.8887164829181979
# c: 100 t: 3 fscore: 0.9186558276808369
# c: 100 t: 4 fscore: 0.838709677419355
# c: 100 t: 0 fscore: 0.9039685908319185
# c: 100 t: 1 fscore: 0.8064516129032258
# c: 100 t: 2 fscore: 0.8874303587984023
# c: 100 t: 3 fscore: 0.870967741935484
# c: 100 t: 4 fscore: 0.9044812554489974
# c: 100 t: 0 fscore: 0.8443295492862763
# c: 100 t: 1 fscore: 0.8719581211092247
# c: 100 t: 2 fscore: 0.8199596232660098
# c: 100 t: 3 fscore: 0.9012463343108504
# c: 100 t: 4 fscore: 0.8869489564064228
# c: 100 t: 0 fscore: 0.8541445487954267
# c: 100 t: 1 fscore: 0.8503597395087825
# c: 100 t: 2 fscore: 0.7708769297587554
# c: 100 t: 3 fscore: 0.8247867437984115
# c: 100 t: 4 fscore: 0.8064516129032258
# c: 100 t: 0 fscore: 0.7903592375366568
# c: 100 t: 1 fscore: 0.9054541595925297
# c: 100 t: 2 fscore: 0.6772440392706873
# c: 100 t: 3 fscore: 0.7800523103748911
# c: 100 t: 4 fscore: 0.7337451384122627
# c: 100 t: 0 fscore: nan
# c: 100 t: 1 fscore: 0.7964320625610948
# c: 100 t: 2 fscore: 0.4538766270514997
# c: 100 t: 3 fscore: 0.7632925472747497
# c: 100 t: 4 fscore: 0.7431626928471248

# %%
gs2d_res = sort_and_filter(gs2d_res)
gpol_res = sort_and_filter(gpol_res)
gexp_res = sort_and_filter(gexp_res)

# %%
best_s2d_geyser = gs2d_res[0]
print("c:", best_s2d_geyser[2], "avg f:", best_s2d_geyser[1])
draw_on_data(best_s2d_geyser[0], gdata)
# Out:
# c: 1 avg f: 0.8461561226653724
# No handles with labels found to put in legend.

# %%
best_exp_geyser = gexp_res[0]
print("c:", best_exp_geyser[2], "gamma:", best_exp_geyser[3], "avg f:", best_exp_geyser[1])
draw_on_data(best_exp_geyser[0], gdata)
# Out:
# c: 1 gamma: 0.8 avg f: 0.9063129521287335
# No handles with labels found to put in legend.

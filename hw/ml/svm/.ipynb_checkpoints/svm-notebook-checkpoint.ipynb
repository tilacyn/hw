# %%
import pandas as pd
import numpy as np
import plots
import smoduginets
import kernels
import math


class_dict = {
    'N': -1,
    'P': 1
}

def fscore_inner(precision, recall):
    return 2 * (precision * recall) / (precision + recall)

def fscore(classify, test_set):
    mtx = np.array([[0, 0], [0, 0]])
    for x in test_set:
        classified = classify(x)
        expected = class_dict[x[2]]
        if expected == -1 and classified == -1:
            mtx[0][0] += 1
        if expected == 1 and classified == -1:
            mtx[1][0] += 1
        if expected == -1 and classified == 1:
            mtx[0][1] += 1
        if expected == 1 and classified == 1:
            mtx[1][1] += 1
    w = mtx.sum(0)
    w = list(map(lambda x: x / mtx.sum(), w))
    f1 = fscore_inner(mtx[0][0] / mtx.sum(0)[0], mtx[0][0] / mtx.sum(1)[0])
    f2 = fscore_inner(mtx[1][1] / mtx.sum(0)[1], mtx[1][1] / mtx.sum(1)[1])
    return f1 * w[0] + f2 * w[1], mtx



def draw(classify, data):
    return plots.draw(classify, data, minmax[0], minmax[1], minmax[2], minmax[3])

def draw_on_data(model, data):
    draw(model.predict, data)

def separate(data, k):
    shuffled = data.copy()
    np.random.shuffle(shuffled)
    return shuffled[:k], shuffled[k:]


def run_svm(kernel_f, train_set, c):
    n = len(train_set)
    kernel = np.zeros([n, n])
    y = []

    for i in range(n):
        for j in range(n):
            kernel[i][j] = kernel_f(train_set[i], train_set[j])
        y.append(class_dict[train_set[i][2]])

    smo_model = smoduginets.SMO(train_set, kernel, kernel_f, y, c)
    smo_model.solve()

    #draw(lambda x: smo_model.predict(train_set, x), train_set)
    return smo_model


times = range(5)

def run_cv(kernel, data, train_set_n, c):
    sum_f = 0
    for t in times:
        train_set, test_set = separate(data, train_set_n)
        model = run_svm(kernel, train_set, c)
        f, mtx = fscore(model.predict, test_set)
        print("c:", c, "t:", t, "fscore:", f)
        sum_f += f
    return [model, sum_f / len(times), c]


def sort_and_filter(res):
    res = list(filter(lambda x: not math.isnan(x[1]), res))
    res.sort(key=lambda x: -x[1])
    return res

minmax = []

def run(train_set_n, file):
    minmax.clear()
    dataframe = pd.read_csv(file)

    dataframe.info()

    data = dataframe.values

    minmax.append(min(data, key=lambda x: x[1])[1])
    minmax.append(max(data, key=lambda x: x[1])[1])
    minmax.append(min(data, key=lambda x: x[0])[0])
    minmax.append(max(data, key=lambda x: x[0])[0])
    cs = [1, 5, 10, 100]
    gammas = np.linspace(0.2, 1.6, 8)

    exp_results = []
    pol_results = []
    s2d_results = []

    for c in cs:
        for gamma in gammas:
            result = run_cv(kernels.exponentialg(gamma), data, train_set_n, c)
            result.append(gamma)
            exp_results.append(result)

        s2d_result = run_cv(kernels.scalar_2d, data, train_set_n, c)
        s2d_results.append(s2d_result)

        pol_result = run_cv(kernels.polynomial2, data, train_set_n, c)
        pol_results.append(pol_result)

    exp_res = sort_and_filter(exp_results)
    s2d_res = sort_and_filter(s2d_results)
    pol_res = sort_and_filter(pol_results)

    return exp_res, s2d_res, pol_res, data

# %%
exp_res, s2d_res, pol_res, data = run(80, 'data/chips.csv')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 118 entries, 0 to 117
# Data columns (total 3 columns):
# x        118 non-null float64
# y        118 non-null float64
# class    118 non-null object
# dtypes: float64(2), object(1)
# memory usage: 2.9+ KB
# c: 1 t: 0 fscore: 0.7485902255639098
# c: 1 t: 1 fscore: 0.59688995215311
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:33: RuntimeWarning: invalid value encountered in long_scalars
# c: 1 t: 2 fscore: nan
# c: 1 t: 3 fscore: 0.4457236842105263
# c: 1 t: 4 fscore: nan
# c: 1 t: 0 fscore: 0.7077067669172933
# c: 1 t: 1 fscore: 0.6842105263157895
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:32: RuntimeWarning: invalid value encountered in long_scalars
# c: 1 t: 2 fscore: nan
# c: 1 t: 3 fscore: 0.7147625160462132
# c: 1 t: 4 fscore: nan
# c: 1 t: 0 fscore: 0.6629011553273427
# c: 1 t: 1 fscore: nan
# c: 1 t: 2 fscore: nan
# c: 1 t: 3 fscore: 0.7636530350265909
# c: 1 t: 4 fscore: 0.637719298245614
# c: 1 t: 0 fscore: 0.7233538391433129
# c: 1 t: 1 fscore: 0.6782252770591187
# c: 1 t: 2 fscore: nan
# c: 1 t: 3 fscore: 0.6177812395682653
# c: 1 t: 4 fscore: 0.7623372360214467
# c: 1 t: 0 fscore: 0.660502607871029
# c: 1 t: 1 fscore: 0.59688995215311
# c: 1 t: 2 fscore: 0.6586059743954481
# c: 1 t: 3 fscore: 0.7646433156060886
# c: 1 t: 4 fscore: 0.8421052631578947
# c: 1 t: 0 fscore: 0.8953265516733009
# c: 1 t: 1 fscore: 0.7144736842105261
# c: 1 t: 2 fscore: nan
# c: 1 t: 3 fscore: 0.7091220775431302
# c: 1 t: 4 fscore: 0.6895179124281291
# c: 1 t: 0 fscore: nan
# c: 1 t: 1 fscore: 0.6590801327643433
# c: 1 t: 2 fscore: 0.6791902834008097
# c: 1 t: 3 fscore: 0.7346491228070176
# c: 1 t: 4 fscore: 0.669956140350877
# c: 1 t: 0 fscore: 0.6550503242232566
# c: 1 t: 1 fscore: 0.7906531033466018
# c: 1 t: 2 fscore: 0.6143407298734642
# c: 1 t: 3 fscore: 0.8159171317066054
# c: 1 t: 4 fscore: 0.50834008097166
# c: 1 t: 0 fscore: nan
# c: 1 t: 1 fscore: 0.5493717887828677
# c: 1 t: 2 fscore: nan
# c: 1 t: 3 fscore: 0.41624793691545947
# c: 1 t: 4 fscore: 0.388410049514029
# c: 1 t: 0 fscore: 0.687218045112782
# c: 1 t: 1 fscore: 0.6823116615067081
# c: 1 t: 2 fscore: 0.5629194938565928
# c: 1 t: 3 fscore: 0.7370012332418348
# c: 1 t: 4 fscore: 0.608819345661451
# c: 5 t: 0 fscore: 0.46099922109714037
# c: 5 t: 1 fscore: 0.6333603238866397
# c: 5 t: 2 fscore: 0.7639924335150773
# c: 5 t: 3 fscore: 0.6038953933690776
# c: 5 t: 4 fscore: 0.6154527733475101
# c: 5 t: 0 fscore: 0.6827431748851218
# c: 5 t: 1 fscore: 0.8161745827984597
# c: 5 t: 2 fscore: 0.7639785534522376
# c: 5 t: 3 fscore: 0.5554373739226114
# c: 5 t: 4 fscore: 0.788888888888889
# c: 5 t: 0 fscore: 0.7894736842105263
# c: 5 t: 1 fscore: 0.7135521731157162
# c: 5 t: 2 fscore: 0.7127329758908707
# c: 5 t: 3 fscore: 0.7894736842105263
# c: 5 t: 4 fscore: 0.7111281321807639
# c: 5 t: 0 fscore: 0.660502607871029
# c: 5 t: 1 fscore: 0.8164277637961848
# c: 5 t: 2 fscore: 0.7148839841539332
# c: 5 t: 3 fscore: 0.7646350804245541
# c: 5 t: 4 fscore: 0.8421052631578947
# c: 5 t: 0 fscore: 0.7623233559586069
# c: 5 t: 1 fscore: 0.7009692242344674
# c: 5 t: 2 fscore: 0.6930561698363557
# c: 5 t: 3 fscore: 0.7119305540358172
# c: 5 t: 4 fscore: 0.6859796550199027
# c: 5 t: 0 fscore: 0.8429824561403509
# c: 5 t: 1 fscore: 0.694976076555024
# c: 5 t: 2 fscore: 0.7918325224826774
# c: 5 t: 3 fscore: 0.8421052631578948
# c: 5 t: 4 fscore: 0.7390350877192983
# c: 5 t: 0 fscore: 0.7900584795321638
# c: 5 t: 1 fscore: 0.7091220775431302
# c: 5 t: 2 fscore: 0.8164277637961848
# c: 5 t: 3 fscore: 0.8421052631578947
# c: 5 t: 4 fscore: 0.9211073421599737
# c: 5 t: 0 fscore: 0.7918325224826774
# c: 5 t: 1 fscore: 0.8421052631578947
# c: 5 t: 2 fscore: 0.764306816938396
# c: 5 t: 3 fscore: 0.8690813054140729
# c: 5 t: 4 fscore: 0.8429824561403509
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:15: RuntimeWarning: invalid value encountered in double_scalars
#   from ipykernel import kernelapp as app
# c: 5 t: 0 fscore: nan
# c: 5 t: 1 fscore: 0.5535616588248168
# c: 5 t: 2 fscore: 0.5316231755860239
# c: 5 t: 3 fscore: 0.4054003931604911
# c: 5 t: 4 fscore: 0.5254803675856307
# c: 5 t: 0 fscore: 0.6356725146198831
# c: 5 t: 1 fscore: 0.7646433156060886
# c: 5 t: 2 fscore: 0.7412649270234409
# c: 5 t: 3 fscore: 0.7894736842105263
# c: 5 t: 4 fscore: 0.7200834073444802
# c: 10 t: 0 fscore: 0.8159171317066054
# c: 10 t: 1 fscore: nan
# c: 10 t: 2 fscore: 0.7390350877192983
# c: 10 t: 3 fscore: 0.5789473684210527
# c: 10 t: 4 fscore: 0.788888888888889
# c: 10 t: 0 fscore: 0.7629937629937629
# c: 10 t: 1 fscore: 0.7103257103257103
# c: 10 t: 2 fscore: 0.788888888888889
# c: 10 t: 3 fscore: 0.8425438596491228
# c: 10 t: 4 fscore: 0.7957393483709273
# c: 10 t: 0 fscore: 0.7656615110715477
# c: 10 t: 1 fscore: 0.791812865497076
# c: 10 t: 2 fscore: 0.7894736842105263
# c: 10 t: 3 fscore: 0.7633220264799211
# c: 10 t: 4 fscore: 0.8421052631578947
# c: 10 t: 0 fscore: 0.7629937629937629
# c: 10 t: 1 fscore: 0.7135862913096696
# c: 10 t: 2 fscore: 0.6595542911332385
# c: 10 t: 3 fscore: 0.7906531033466018
# c: 10 t: 4 fscore: 0.7667232597623088
# c: 10 t: 0 fscore: 0.8154043645699615
# c: 10 t: 1 fscore: 0.7309450095827806
# c: 10 t: 2 fscore: 0.7176662586699307
# c: 10 t: 3 fscore: 0.7397906531033467
# c: 10 t: 4 fscore: 0.7714770797962648
# c: 10 t: 0 fscore: 0.7926065162907269
# c: 10 t: 1 fscore: 0.7148839841539332
# c: 10 t: 2 fscore: 0.7368421052631579
# c: 10 t: 3 fscore: 0.8156618156618156
# c: 10 t: 4 fscore: 0.8164385594006157
# c: 10 t: 0 fscore: 0.8421052631578947
# c: 10 t: 1 fscore: 0.8664402942840974
# c: 10 t: 2 fscore: 0.765633596185586
# c: 10 t: 3 fscore: 0.8154043645699615
# c: 10 t: 4 fscore: 0.7390350877192983
# c: 10 t: 0 fscore: 0.8011336032388663
# c: 10 t: 1 fscore: 0.7091220775431302
# c: 10 t: 2 fscore: 0.6600284495021337
# c: 10 t: 3 fscore: 0.6581318160265528
# c: 10 t: 4 fscore: 0.7930622009569378
# c: 10 t: 0 fscore: nan
# c: 10 t: 1 fscore: 0.42105263157894735
# c: 10 t: 2 fscore: 0.45314505776636715
# c: 10 t: 3 fscore: 0.4340262420757777
# c: 10 t: 4 fscore: nan
# c: 10 t: 0 fscore: 0.790643274853801
# c: 10 t: 1 fscore: 0.765633596185586
# c: 10 t: 2 fscore: nan
# c: 10 t: 3 fscore: 0.7639785534522376
# c: 10 t: 4 fscore: 0.5954592363261094
# c: 100 t: 0 fscore: 0.6842105263157895
# c: 100 t: 1 fscore: 0.6600284495021337
# c: 100 t: 2 fscore: 0.8194385450052131
# c: 100 t: 3 fscore: 0.7346491228070176
# c: 100 t: 4 fscore: 0.6077388593434807
# c: 100 t: 0 fscore: 0.8138422165349949
# c: 100 t: 1 fscore: 0.6518675123326286
# c: 100 t: 2 fscore: 0.8664402942840974
# c: 100 t: 3 fscore: 0.7606542784021363
# c: 100 t: 4 fscore: 0.7368421052631577
# c: 100 t: 0 fscore: 0.769100169779287
# c: 100 t: 1 fscore: 0.7894736842105263
# c: 100 t: 2 fscore: 0.7689996661844889
# c: 100 t: 3 fscore: 0.7882942650744508
# c: 100 t: 4 fscore: 0.6859649122807017
# c: 100 t: 0 fscore: 0.8148651197887191
# c: 100 t: 1 fscore: 0.8421052631578947
# c: 100 t: 2 fscore: 0.6639219613515819
# c: 100 t: 3 fscore: 0.8151403879678054
# c: 100 t: 4 fscore: 0.8190349022662364
# c: 100 t: 0 fscore: 0.7147625160462132
# c: 100 t: 1 fscore: 0.8429824561403509
# c: 100 t: 2 fscore: 0.7623372360214467
# c: 100 t: 3 fscore: 0.8681459746928295
# c: 100 t: 4 fscore: 0.7894736842105263
# c: 100 t: 0 fscore: 0.764721782445843
# c: 100 t: 1 fscore: 0.8169448010269577
# c: 100 t: 2 fscore: 0.8146341463414635
# c: 100 t: 3 fscore: 0.8438743918620079
# c: 100 t: 4 fscore: 0.7368421052631577
# c: 100 t: 0 fscore: 0.8138639281129654
# c: 100 t: 1 fscore: 0.8169448010269577
# c: 100 t: 2 fscore: 0.7900584795321638
# c: 100 t: 3 fscore: 0.7368421052631577
# c: 100 t: 4 fscore: 0.7636530350265909
# c: 100 t: 0 fscore: 0.7383163791832523
# c: 100 t: 1 fscore: 0.7383040935672515
# c: 100 t: 2 fscore: 0.7397906531033467
# c: 100 t: 3 fscore: 0.7656615110715477
# c: 100 t: 4 fscore: 0.8146341463414635
# c: 100 t: 0 fscore: 0.5545112781954887
# c: 100 t: 1 fscore: 0.38965059708093763
# c: 100 t: 2 fscore: 0.45004048582995954
# c: 100 t: 3 fscore: nan
# c: 100 t: 4 fscore: 0.44851734325418535
# c: 100 t: 0 fscore: 0.7633220264799211
# c: 100 t: 1 fscore: 0.7589852008456659
# c: 100 t: 2 fscore: 0.7111281321807639
# c: 100 t: 3 fscore: 0.6630447085455574
# c: 100 t: 4 fscore: 0.5010395010395011

# %%
for i in range(1):
    print("c:", exp_res[i][2], "gamma:", exp_res[i][3], "avg f:", exp_res[i][1])
    draw_on_data(exp_res[i][0], data)
# Out:
# c: 5 gamma: 1.6 avg f: 0.8220616728266783
# No handles with labels found to put in legend.

# %%
for i in range(1):
    #print("c:", s2d_res[i][2], "avg f:", s2d_res[i][1])
    draw_on_data(pol_res[i][0], data)
# Out:
# [[<smoduginets.SMO object at 0x7fd3acb20358>, 0.7302275697608838, 5], [<smoduginets.SMO object at 0x7fd3acb20d68>, 0.6795039138182819, 100], [<smoduginets.SMO object at 0x7fd3acb200f0>, 0.6556539558758738, 1]]
# No handles with labels found to put in legend.

# %%
gexp_res, gs2d_res, gpol_res, gdata = run(160, 'data/geyser.csv')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 222 entries, 0 to 221
# Data columns (total 3 columns):
# x        222 non-null int64
# y        222 non-null float64
# class    222 non-null object
# dtypes: float64(1), int64(1), object(1)
# memory usage: 5.3+ KB
# c: 1 t: 0 fscore: 0.8661626883446383
# c: 1 t: 1 fscore: 0.877726574500768
# c: 1 t: 2 fscore: 0.8739388794567062
# c: 1 t: 3 fscore: 0.8453079178885631
# c: 1 t: 4 fscore: 0.9682157381450627
# c: 1 t: 0 fscore: 0.8611298089369854
# c: 1 t: 1 fscore: 0.904711375212224
# c: 1 t: 2 fscore: 0.9218431554700313
# c: 1 t: 3 fscore: 0.9200696628629357
# c: 1 t: 4 fscore: 0.843565730142213
# c: 1 t: 0 fscore: 0.9046472144351878
# c: 1 t: 1 fscore: 0.9208478287658897
# c: 1 t: 2 fscore: 0.8910134773512383
# c: 1 t: 3 fscore: 0.9047766749379652
# c: 1 t: 4 fscore: 0.8730355665839536
# c: 1 t: 0 fscore: 0.8569831821371942
# c: 1 t: 1 fscore: 0.9523070641077991
# c: 1 t: 2 fscore: 0.9207812157120913
# c: 1 t: 3 fscore: 0.904215542521994
# c: 1 t: 4 fscore: 0.923248794216536
# c: 1 t: 0 fscore: 0.8139843068875328
# c: 1 t: 1 fscore: 0.8914810249626712
# c: 1 t: 2 fscore: 0.9228498938538807
# c: 1 t: 3 fscore: 0.8908760945510639
# c: 1 t: 4 fscore: 0.8181874039938556
# c: 1 t: 0 fscore: 0.8636462486408119
# c: 1 t: 1 fscore: 0.9207812157120913
# c: 1 t: 2 fscore: 0.9359790605546123
# c: 1 t: 3 fscore: 0.8932347252703206
# c: 1 t: 4 fscore: 0.9203192373963807
# c: 1 t: 0 fscore: 0.8901762477656452
# c: 1 t: 1 fscore: 0.8138794567062819
# c: 1 t: 2 fscore: 0.8785485845145496
# c: 1 t: 3 fscore: 0.9208478287658897
# c: 1 t: 4 fscore: 0.9366645582964369
# c: 1 t: 0 fscore: 0.905815082533175
# c: 1 t: 1 fscore: 0.8730355665839536
# c: 1 t: 2 fscore: 0.9208478287658897
# c: 1 t: 3 fscore: 0.8887646972178176
# c: 1 t: 4 fscore: 0.889727324655022
# c: 1 t: 0 fscore: 0.762929523141655
# c: 1 t: 1 fscore: 0.8033573794292455
# c: 1 t: 2 fscore: 0.5771505376344086
# c: 1 t: 3 fscore: 0.5264419862909911
# c: 1 t: 4 fscore: 0.7525659824046921
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:33: RuntimeWarning: invalid value encountered in long_scalars
# c: 1 t: 0 fscore: nan
# c: 1 t: 1 fscore: 0.8552676041693743
# c: 1 t: 2 fscore: 0.78809937306778
# c: 1 t: 3 fscore: 0.7687634408602151
# c: 1 t: 4 fscore: 0.792421367373929
# c: 5 t: 0 fscore: 0.8914080371944839
# c: 5 t: 1 fscore: 0.9061950146627565
# c: 5 t: 2 fscore: 0.8629008559809656
# c: 5 t: 3 fscore: 0.8908760945510639
# c: 5 t: 4 fscore: 0.877726574500768
# c: 5 t: 0 fscore: 0.8444636242672707
# c: 5 t: 1 fscore: 0.9199143677322046
# c: 5 t: 2 fscore: 0.8401481641313338
# c: 5 t: 3 fscore: 0.8865568712853318
# c: 5 t: 4 fscore: 0.9047766749379652
# c: 5 t: 0 fscore: 0.8725941989699104
# c: 5 t: 1 fscore: 0.9205117735129986
# c: 5 t: 2 fscore: 0.8955948664585501
# c: 5 t: 3 fscore: 0.922486446401908
# c: 5 t: 4 fscore: 0.8780518659076534
# c: 5 t: 0 fscore: 0.8726416739319964
# c: 5 t: 1 fscore: 0.8709677419354838
# c: 5 t: 2 fscore: 0.7442370626101342
# c: 5 t: 3 fscore: 0.8749266862170089
# c: 5 t: 4 fscore: 0.8739650069311754
# c: 5 t: 0 fscore: 0.855788966880369
# c: 5 t: 1 fscore: 0.778221311180638
# c: 5 t: 2 fscore: 0.907991202346041
# c: 5 t: 3 fscore: 0.8262574762231591
# c: 5 t: 4 fscore: 0.8903724964123041
# c: 5 t: 0 fscore: 0.8877126689079677
# c: 5 t: 1 fscore: 0.8602536790594444
# c: 5 t: 2 fscore: 0.8572143035758939
# c: 5 t: 3 fscore: 0.9070276497695853
# c: 5 t: 4 fscore: 0.9210334257772588
# c: 5 t: 0 fscore: 0.8736070381231671
# c: 5 t: 1 fscore: 0.8556419737345403
# c: 5 t: 2 fscore: 0.8268227394401342
# c: 5 t: 3 fscore: 0.8804132405650432
# c: 5 t: 4 fscore: 0.8421560518334714
# c: 5 t: 0 fscore: 0.8575260917786014
# c: 5 t: 1 fscore: 0.8189038140994216
# c: 5 t: 2 fscore: 0.9359790605546123
# c: 5 t: 3 fscore: 0.8726416739319964
# c: 5 t: 4 fscore: 0.8908760945510639
# c: 5 t: 0 fscore: 0.6737327188940092
# c: 5 t: 1 fscore: 0.7577815506508205
# c: 5 t: 2 fscore: nan
# c: 5 t: 3 fscore: 0.7570971690290994
# c: 5 t: 4 fscore: 0.8743156059285091
# c: 5 t: 0 fscore: 0.7294796811162827
# c: 5 t: 1 fscore: nan
# c: 5 t: 2 fscore: nan
# c: 5 t: 3 fscore: nan
# c: 5 t: 4 fscore: 0.7011094878982903
# c: 10 t: 0 fscore: 0.8594601711652403
# c: 10 t: 1 fscore: 0.874929258630447
# c: 10 t: 2 fscore: 0.8744201100442335
# c: 10 t: 3 fscore: 0.9202106649111259
# c: 10 t: 4 fscore: 0.8277282086479065
# c: 10 t: 0 fscore: 0.9197947635056912
# c: 10 t: 1 fscore: 0.8925801586143142
# c: 10 t: 2 fscore: 0.8439407149084568
# c: 10 t: 3 fscore: 0.9362331872166648
# c: 10 t: 4 fscore: 0.8734786399302529
# c: 10 t: 0 fscore: 0.8560969295293324
# c: 10 t: 1 fscore: 0.8749266862170089
# c: 10 t: 2 fscore: 0.8862199240397238
# c: 10 t: 3 fscore: 0.8444636242672707
# c: 10 t: 4 fscore: 0.8804132405650432
# c: 10 t: 0 fscore: 0.904215542521994
# c: 10 t: 1 fscore: 0.8872445919806737
# c: 10 t: 2 fscore: 0.9365428478331703
# c: 10 t: 3 fscore: 0.8387096774193549
# c: 10 t: 4 fscore: 0.9032258064516129
# c: 10 t: 0 fscore: 0.9214518717961995
# c: 10 t: 1 fscore: 0.9219562955254943
# c: 10 t: 2 fscore: 0.8397558849171753
# c: 10 t: 3 fscore: 0.8890937019969278
# c: 10 t: 4 fscore: 0.8408020924149956
# c: 10 t: 0 fscore: 0.8567129924773684
# c: 10 t: 1 fscore: 0.8881380424157423
# c: 10 t: 2 fscore: 0.8267143673150348
# c: 10 t: 3 fscore: 0.8702784670526607
# c: 10 t: 4 fscore: 0.8251357811958882
# c: 10 t: 0 fscore: 0.8773216031280548
# c: 10 t: 1 fscore: 0.8397558849171753
# c: 10 t: 2 fscore: 0.9034280513702093
# c: 10 t: 3 fscore: 0.9019585253456222
# c: 10 t: 4 fscore: 0.7942043547913131
# c: 10 t: 0 fscore: 0.7864408064990094
# c: 10 t: 1 fscore: 0.9048142717497556
# c: 10 t: 2 fscore: 0.8867631895886945
# c: 10 t: 3 fscore: 0.8443295492862763
# c: 10 t: 4 fscore: 0.8235484797125208
# c: 10 t: 0 fscore: nan
# c: 10 t: 1 fscore: 0.6859600614439324
# c: 10 t: 2 fscore: nan
# c: 10 t: 3 fscore: 0.7970863683662851
# c: 10 t: 4 fscore: 0.8734786399302529
# c: 10 t: 0 fscore: 0.6841505721534717
# c: 10 t: 1 fscore: nan
# c: 10 t: 2 fscore: 0.8453079178885631
# c: 10 t: 3 fscore: 0.4916290193994154
# c: 10 t: 4 fscore: 0.7415559772296016
# c: 100 t: 0 fscore: 0.8387096774193548
# c: 100 t: 1 fscore: 0.9210261255559814
# c: 100 t: 2 fscore: 0.9200696628629357
# c: 100 t: 3 fscore: 0.8481857306431871
# c: 100 t: 4 fscore: 0.9060686224187625
# c: 100 t: 0 fscore: 0.9061950146627565
# c: 100 t: 1 fscore: 0.7884640378466898
# c: 100 t: 2 fscore: 0.870967741935484
# c: 100 t: 3 fscore: 0.9359790605546123
# c: 100 t: 4 fscore: 0.854952264793708
# c: 100 t: 0 fscore: 0.771236559139785
# c: 100 t: 1 fscore: 0.8408020924149956
# c: 100 t: 2 fscore: 0.8421560518334714
# c: 100 t: 3 fscore: 0.7399547255234862
# c: 100 t: 4 fscore: 0.8569831821371942
# c: 100 t: 0 fscore: 0.7907093374134049
# c: 100 t: 1 fscore: 0.7233760494918251
# c: 100 t: 2 fscore: 0.9198010965191892
# c: 100 t: 3 fscore: 0.8077070619006103
# c: 100 t: 4 fscore: 0.9191165639919248
# c: 100 t: 0 fscore: 0.774193548387097
# c: 100 t: 1 fscore: 0.7953359647928859
# c: 100 t: 2 fscore: 0.918969193775237
# c: 100 t: 3 fscore: 0.8268227394401342
# c: 100 t: 4 fscore: 0.8690725312907173
# c: 100 t: 0 fscore: 0.8262735367099694
# c: 100 t: 1 fscore: 0.8415866508433129
# c: 100 t: 2 fscore: 0.7402615518744552
# c: 100 t: 3 fscore: 0.8354105571847507
# c: 100 t: 4 fscore: 0.8074855252274606
# c: 100 t: 0 fscore: 0.8709677419354838
# c: 100 t: 1 fscore: 0.8056323604710702
# c: 100 t: 2 fscore: 0.8506270668247333
# c: 100 t: 3 fscore: 0.8518364482337345
# c: 100 t: 4 fscore: 0.7910642966864164
# c: 100 t: 0 fscore: 0.840432864626413
# c: 100 t: 1 fscore: 0.8440045617464973
# c: 100 t: 2 fscore: 0.9023627144244255
# c: 100 t: 3 fscore: 0.8722873900293254
# c: 100 t: 4 fscore: 0.8064516129032258
# c: 100 t: 0 fscore: 0.9357535308592038
# c: 100 t: 1 fscore: 0.8480761305308907
# c: 100 t: 2 fscore: 0.617984664942607
# c: 100 t: 3 fscore: 0.7882907181644909
# c: 100 t: 4 fscore: 0.7816404191792049
# c: 100 t: 0 fscore: 0.7299796977216332
# c: 100 t: 1 fscore: nan
# c: 100 t: 2 fscore: 0.8311973921082081
# c: 100 t: 3 fscore: 0.8166457198715263
# c: 100 t: 4 fscore: nan

# %%
for i in range(1):
    print("c:", gexp_res[i][2], "gamma:", gexp_res[i][3], "avg f:", gexp_res[i][1])
    draw_on_data(gexp_res[i][0], gdata)
# Out:
# c: 1 gamma: 0.8 avg f: 0.9115071597391229
# No handles with labels found to put in legend.

# %%
for i in range(1):
    draw_on_data(gs2d_res[i][0], gdata)
# Out:
# No handles with labels found to put in legend.
